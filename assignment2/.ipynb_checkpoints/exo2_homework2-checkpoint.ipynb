# %% [markdown]
# # Problem 2: Dogs vs. Cats Classification
# We first import some libraries, define the data loader and training procedures. We will define the first simple model below

# %%
from __future__ import print_function
# Pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable


# Plotting
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
batch_size = 256
epochs = 50
lr = 3e-4
cuda = torch.cuda.is_available()
print('Using cuda:', cuda)
init = 'glorot_uniform'
# Out:
# Using cuda: True

# %% [markdown]
# Notice that to increase the performance of our model, we add some data augmentation to the training set. Namely we add some random horizontal flippings, some random brightness change and small random rotations to the input.

# %%
kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}



train_set = datasets.ImageFolder(root='/data/milatmp1/thomasva/data/competitions/dogsvscats/train_64x64',
                            transform=transforms.Compose([
                                transforms.Resize(64),
                                transforms.CenterCrop(64),
                                transforms.RandomHorizontalFlip(),
                                transforms.ColorJitter(),
                                transforms.RandomRotation(15),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                            ]))

val_set = datasets.ImageFolder(root='/data/milatmp1/thomasva/data/competitions/dogsvscats/valid_64x64',
                            transform=transforms.Compose([
                                transforms.Resize(64),
                                transforms.CenterCrop(64),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                            ]))

train_loader = torch.utils.data.DataLoader(
        train_set, shuffle=True,
        batch_size=batch_size, **kwargs)

valid_loader = torch.utils.data.DataLoader(
        val_set, shuffle=True,
        batch_size=batch_size, **kwargs)

# %%
def train(loader, epoch, net):
    net.train()
    loss_tot = 0
    correct = 0
    for batch_idx, (data, target) in enumerate(loader):
        if cuda:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target).unsqueeze(1).float()
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target)

        pred = output.data.round()
        correct += pred.eq(target.data.view_as(pred)).cpu().float().mean()
        loss_tot += loss.data[0]

        loss.backward()
        optimizer.step()

        #if batch_idx % log_interval == 0:
        #    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
        #        epoch, batch_idx * len(data), len(loader.dataset),
        #        100. * batch_idx / len(loader), loss.data[0]))
    steps = batch_idx + 1
    return loss_tot/steps, correct/steps

def test(loader, net):
    net.eval()
    test_loss = 0
    correct = 0
    for batch_idx, (data, target) in enumerate(loader):
        if cuda:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data, volatile=True), Variable(target).unsqueeze(1).float()
        output = net(data)
        test_loss += criterion(output, target).data[0]
        pred = output.data.round()
        correct += pred.eq(target.data.view_as(pred)).cpu().float().mean()

    steps = batch_idx + 1
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss/steps, int(correct/steps*len(loader.dataset)), len(loader.dataset),
        100. * correct / steps))
    return test_loss / steps, correct / steps

# %%
def init_glorot_uniform(m):
    gain = nn.init.calculate_gain('relu')
    if type(m) == nn.Linear:
        nn.init.xavier_uniform(m.weight,gain=gain)
        nn.init.constant(m.bias,0)

def init_glorot_normal(m):
    gain = nn.init.calculate_gain('relu')
    if type(m) == nn.Linear:
        nn.init.xavier_normal(m.weight,gain=gain)
        nn.init.constant(m.bias,0)

# %%
def nparams(model):
    return sum(p.numel() for p in model.parameters())

# %% [markdown]
# ## (a) Architecture
# ### A first simple model
# For the first model, we took inspiration from the DCGAN's discriminator architecture which only has convolutional layers to beginning to end.
# This has a fairly low number of parameters and is training is faster that with big linear layers.
#
# The network has 5 convolutional layers and uses ReLU activations.
# The simplest way to explain this architecture is to say that each convolutional layer reduces the feature map size by 2 on each dimension (because of the stride of 2, and the padding of 1), and we augment the number of channels by 2 everytime.
#
# We do not use dilations, and we do not use batchnorm or any regularization here.
#
# The number of parameters in this model is 2,764,737
#
# In this part and the following, we always use the Adam optimizer with default $\beta$ parameters and a learning rate of 1e-4. While we could probably achieve better generalization (and accuracy!) with plain SGD, this would require a bit of tuning and Adam works pretty well out of the box

# %%
class netCNN5(nn.Module):
    def __init__(self):
        super(netCNN5, self).__init__()
        self.main = nn.Sequential(
            # input is 3 x 64 x 64
            nn.Conv2d(3, 64, 4, 2, 1, bias=True),
            nn.ReLU(inplace=True),
            # size 64 x 32 x 32
            nn.Conv2d(64, 128, 4, 2, 1, bias=True),
            nn.ReLU(inplace=True),
            # size 128 x 16 x 16
            nn.Conv2d(128, 256, 4, 2, 1, bias=True),
            nn.ReLU(inplace=True),
            # size 256 x 8 x 8
            nn.Conv2d(256, 512, 4, 2, 1, bias=True),
            nn.ReLU(inplace=True),
            # size 512 x 4 x 4
            nn.Conv2d(512, 1, 4, 1, 0, bias=True),
            # size 1 x 1 x 1
            nn.Sigmoid()
        )

    def forward(self, input):
        output = self.main(input)
        return output.view(-1, 1)

# %%
model = netCNN5()
criterion = nn.BCELoss()


if init == 'glorot_uniform':
    model.apply(init_glorot_uniform)
elif init == 'glorot_normal':
    model.apply(init_glorot_normal)


if cuda:
    model.cuda()

optimizer = optim.Adam(model.parameters(), lr=lr)

list_err_tr = []
list_loss_tr = []
list_err_val = []
list_loss_val = []
best_valid_acc = 0

for epoch in range(1, epochs + 1):
    print('Epoch', epoch, '/', epochs)
    train_loss, train_acc = train(train_loader, epoch, model)
    #train_loss, train_acc = test(train_loader, model)
    valid_loss, valid_acc = test(valid_loader, model)
    
    list_err_tr.append(1-train_acc)
    list_loss_tr.append(train_loss)
    list_err_val.append(1-valid_acc)
    list_loss_val.append(valid_loss)
    
    if valid_acc > best_valid_acc:
        best_valid_acc = valid_acc

print('Best valid accuracy:', best_valid_acc)
# Out:
# Epoch 1 / 50
#
# Test set: Average loss: 0.5896, Accuracy: 3478/4999 (70%)
#
# Epoch 2 / 50
#
# Test set: Average loss: 0.5586, Accuracy: 3550/4999 (71%)
#
# Epoch 3 / 50
#
# Test set: Average loss: 0.5184, Accuracy: 3736/4999 (75%)
#
# Epoch 4 / 50
#
# Test set: Average loss: 0.5014, Accuracy: 3787/4999 (76%)
#
# Epoch 5 / 50
#
# Test set: Average loss: 0.4756, Accuracy: 3850/4999 (77%)
#
# Epoch 6 / 50
#
# Test set: Average loss: 0.4467, Accuracy: 3975/4999 (80%)
#
# Epoch 7 / 50
#
# Test set: Average loss: 0.4463, Accuracy: 3966/4999 (79%)
#
# Epoch 8 / 50
#
# Test set: Average loss: 0.4081, Accuracy: 4053/4999 (81%)
#
# Epoch 9 / 50
#
# Test set: Average loss: 0.4006, Accuracy: 4092/4999 (82%)
#
# Epoch 10 / 50
#
# Test set: Average loss: 0.4006, Accuracy: 4091/4999 (82%)
#
# Epoch 11 / 50
#
# Test set: Average loss: 0.3914, Accuracy: 4129/4999 (83%)
#
# Epoch 12 / 50
#
# Test set: Average loss: 0.3804, Accuracy: 4130/4999 (83%)
#
# Epoch 13 / 50
#
# Test set: Average loss: 0.3712, Accuracy: 4165/4999 (83%)
#
# Epoch 14 / 50
#
# Test set: Average loss: 0.3828, Accuracy: 4170/4999 (83%)
#
# Epoch 15 / 50
#
# Test set: Average loss: 0.3817, Accuracy: 4143/4999 (83%)
#
# Epoch 16 / 50
#
# Test set: Average loss: 0.3732, Accuracy: 4198/4999 (84%)
#
# Epoch 17 / 50
#
# Test set: Average loss: 0.3443, Accuracy: 4235/4999 (85%)
#
# Epoch 18 / 50
#
# Test set: Average loss: 0.3477, Accuracy: 4236/4999 (85%)
#
# Epoch 19 / 50
#
# Test set: Average loss: 0.3932, Accuracy: 4125/4999 (83%)
#
# Epoch 20 / 50
#
# Test set: Average loss: 0.3419, Accuracy: 4260/4999 (85%)
#
# Epoch 21 / 50
#
# Test set: Average loss: 0.3286, Accuracy: 4275/4999 (86%)
#
# Epoch 22 / 50
#
# Test set: Average loss: 0.4207, Accuracy: 4130/4999 (83%)
#
# Epoch 23 / 50
#
# Test set: Average loss: 0.3242, Accuracy: 4302/4999 (86%)
#
# Epoch 24 / 50
#
# Test set: Average loss: 0.3345, Accuracy: 4292/4999 (86%)
#
# Epoch 25 / 50
#
# Test set: Average loss: 0.3788, Accuracy: 4200/4999 (84%)
#
# Epoch 26 / 50
#
# Test set: Average loss: 0.3371, Accuracy: 4275/4999 (86%)
#
# Epoch 27 / 50
#
# Test set: Average loss: 0.3334, Accuracy: 4302/4999 (86%)
#
# Epoch 28 / 50
#
# Test set: Average loss: 0.3452, Accuracy: 4305/4999 (86%)
#
# Epoch 29 / 50
#
# Test set: Average loss: 0.3273, Accuracy: 4317/4999 (86%)
#
# Epoch 30 / 50
#
# Test set: Average loss: 0.3385, Accuracy: 4319/4999 (86%)
#
# Epoch 31 / 50
#
# Test set: Average loss: 0.3395, Accuracy: 4306/4999 (86%)
#
# Epoch 32 / 50
#
# Test set: Average loss: 0.4039, Accuracy: 4224/4999 (85%)
#
# Epoch 33 / 50
#
# Test set: Average loss: 0.3567, Accuracy: 4311/4999 (86%)
#
# Epoch 34 / 50
#
# Test set: Average loss: 0.3490, Accuracy: 4332/4999 (87%)
#
# Epoch 35 / 50
#
# Test set: Average loss: 0.3686, Accuracy: 4280/4999 (86%)
#
# Epoch 36 / 50
#
# Test set: Average loss: 0.4187, Accuracy: 4239/4999 (85%)
#
# Epoch 37 / 50
#
# Test set: Average loss: 0.3937, Accuracy: 4296/4999 (86%)
#
# Epoch 38 / 50
#
# Test set: Average loss: 0.3780, Accuracy: 4284/4999 (86%)
#
# Epoch 39 / 50
#
# Test set: Average loss: 0.4097, Accuracy: 4272/4999 (85%)
#
# Epoch 40 / 50
#
# Test set: Average loss: 0.3966, Accuracy: 4320/4999 (86%)
#
# Epoch 41 / 50
#
# Test set: Average loss: 0.3998, Accuracy: 4312/4999 (86%)
#
# Epoch 42 / 50
#
# Test set: Average loss: 0.4374, Accuracy: 4266/4999 (85%)
#
# Epoch 43 / 50
#
# Test set: Average loss: 0.4202, Accuracy: 4319/4999 (86%)
#
# Epoch 44 / 50
#
# Test set: Average loss: 0.4552, Accuracy: 4205/4999 (84%)
#
# Epoch 45 / 50
#
# Test set: Average loss: 0.5896, Accuracy: 4164/4999 (83%)
#
# Epoch 46 / 50
#
# Test set: Average loss: 0.4493, Accuracy: 4277/4999 (86%)
#
# Epoch 47 / 50
#
# Test set: Average loss: 0.4573, Accuracy: 4280/4999 (86%)
#
# Epoch 48 / 50
#
# Test set: Average loss: 0.4326, Accuracy: 4286/4999 (86%)
#
# Epoch 49 / 50
#
# Test set: Average loss: 0.4431, Accuracy: 4308/4999 (86%)
#
# Epoch 50 / 50
#
# Test set: Average loss: 0.4640, Accuracy: 4323/4999 (86%)
#
# Best valid accuracy: 0.8667505787037036

# %%
plt.plot(np.arange(1, epochs+1), list_err_tr, label='Train_err')
plt.plot(np.arange(1, epochs+1), list_err_val, label='Valid_err')
plt.title('Errors')
plt.legend()

# %%
plt.semilogy(np.arange(1, epochs+1), list_loss_tr, label='Train_loss')
plt.semilogy(np.arange(1, epochs+1), list_loss_val, label='Valid_loss')
plt.title('Loss')
plt.legend()

# %% [markdown]
# #### Observations
# First thing to notice is that we reach the reasonable accuracy of 86.6%. However, we also notice that we overfit from the beginning: while we do not see our validation accuracy rise, the validation loss grows over time and the generalization gap is pretty high.

# %% [markdown]
# ## (b) Improving the model
# ### A better model
# We now consider an improvement over the previous model. To tackle the generalization issue, we will
# - reduce the number of parameters of the model by using filters of size $(3, 3)$ (mostly)
# - add explicit regularization (Dropout here)
#
# We do also make use of classical deep learning techniques such as MaxPooling and BatchNormalization. We also use LeakyReLU instead of ReLU as it can increase a bit our accuracy.
#
# This model has 1,560,961 parameters.

# %%
class betterNet(nn.Module):
    def __init__(self):
        super(betterNet, self).__init__()
        self.main = nn.Sequential(
            # input is 3 x 64 x 64
            nn.Conv2d(3, 64, 3, 1, 1, bias=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.MaxPool2d(2),    
            # size 64 x 32 x 32
            nn.Conv2d(64, 128, 3, 1, 1, bias=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.BatchNorm2d(128),
            nn.Dropout2d(0.2),
            nn.MaxPool2d(2),
            # size 128 x 16 x 16
            nn.Conv2d(128, 256, 3, 1, 1, bias=True),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout2d(0.2),
            nn.MaxPool2d(2),
            # size 256 x 8 x 8
            nn.Conv2d(256, 512, 3, 1, 1, bias=True),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout2d(0.2),
            nn.MaxPool2d(2),
            # size 512 x 4 x 4
            nn.Conv2d(512, 1, 4, 1, 0, bias=True),
            # size 1 x 1 x 1
            nn.Sigmoid()
        )

    def forward(self, input):
        output = self.main(input)
        return output.view(-1, 1)

# %%
model = betterNet()
criterion = nn.BCELoss()

if init == 'glorot_uniform':
    model.apply(init_glorot_uniform)
elif init == 'glorot_normal':
    model.apply(init_glorot_normal)


if cuda:
    model.cuda()

optimizer = optim.Adam(model.parameters(), lr=lr)

list_err_tr2 = []
list_loss_tr2 = []
list_err_val2 = []
list_loss_val2 = []
best_valid_acc2 = 0

for epoch in range(1, epochs + 1):
    print('Epoch', epoch, '/', epochs)
    train_loss, train_acc = train(train_loader, epoch, model)
    #train_loss, train_acc = test(train_loader, model)
    valid_loss, valid_acc = test(valid_loader, model)
    
    list_err_tr2.append(1-train_acc)
    list_loss_tr2.append(train_loss)
    list_err_val2.append(1-valid_acc)
    list_loss_val2.append(valid_loss)
    
    if valid_acc > best_valid_acc2:
        best_valid_acc2 = valid_acc

print('Best valid accuracy:', best_valid_acc2)
# Out:
# Epoch 1 / 50
#
# Test set: Average loss: 0.5566, Accuracy: 3575/4999 (72%)
#
# Epoch 2 / 50
#
# Test set: Average loss: 0.4887, Accuracy: 3824/4999 (77%)
#
# Epoch 3 / 50
#
# Test set: Average loss: 0.4565, Accuracy: 3953/4999 (79%)
#
# Epoch 4 / 50
#
# Test set: Average loss: 0.4268, Accuracy: 4015/4999 (80%)
#
# Epoch 5 / 50
#
# Test set: Average loss: 0.4100, Accuracy: 4035/4999 (81%)
#
# Epoch 6 / 50
#
# Test set: Average loss: 0.3985, Accuracy: 4062/4999 (81%)
#
# Epoch 7 / 50
#
# Test set: Average loss: 0.3724, Accuracy: 4141/4999 (83%)
#
# Epoch 8 / 50
#
# Test set: Average loss: 0.3663, Accuracy: 4169/4999 (83%)
#
# Epoch 9 / 50
#
# Test set: Average loss: 0.3336, Accuracy: 4244/4999 (85%)
#
# Epoch 10 / 50
#
# Test set: Average loss: 0.3382, Accuracy: 4242/4999 (85%)
#
# Epoch 11 / 50
#
# Test set: Average loss: 0.3186, Accuracy: 4300/4999 (86%)
#
# Epoch 12 / 50
#
# Test set: Average loss: 0.3122, Accuracy: 4323/4999 (86%)
#
# Epoch 13 / 50
#
# Test set: Average loss: 0.3003, Accuracy: 4354/4999 (87%)
#
# Epoch 14 / 50
#
# Test set: Average loss: 0.3020, Accuracy: 4347/4999 (87%)
#
# Epoch 15 / 50
#
# Test set: Average loss: 0.2859, Accuracy: 4384/4999 (88%)
#
# Epoch 16 / 50
#
# Test set: Average loss: 0.3060, Accuracy: 4310/4999 (86%)
#
# Epoch 17 / 50
#
# Test set: Average loss: 0.2918, Accuracy: 4382/4999 (88%)
#
# Epoch 18 / 50
#
# Test set: Average loss: 0.2777, Accuracy: 4412/4999 (88%)
#
# Epoch 19 / 50
#
# Test set: Average loss: 0.2691, Accuracy: 4423/4999 (88%)
#
# Epoch 20 / 50
#
# Test set: Average loss: 0.3085, Accuracy: 4344/4999 (87%)
#
# Epoch 21 / 50
#
# Test set: Average loss: 0.2551, Accuracy: 4456/4999 (89%)
#
# Epoch 22 / 50
#
# Test set: Average loss: 0.3149, Accuracy: 4330/4999 (87%)
#
# Epoch 23 / 50
#
# Test set: Average loss: 0.2440, Accuracy: 4476/4999 (90%)
#
# Epoch 24 / 50
#
# Test set: Average loss: 0.2520, Accuracy: 4458/4999 (89%)
#
# Epoch 25 / 50
#
# Test set: Average loss: 0.2491, Accuracy: 4472/4999 (89%)
#
# Epoch 26 / 50
#
# Test set: Average loss: 0.2486, Accuracy: 4480/4999 (90%)
#
# Epoch 27 / 50
#
# Test set: Average loss: 0.2409, Accuracy: 4489/4999 (90%)
#
# Epoch 28 / 50
#
# Test set: Average loss: 0.2534, Accuracy: 4477/4999 (90%)
#
# Epoch 29 / 50
#
# Test set: Average loss: 0.2609, Accuracy: 4463/4999 (89%)
#
# Epoch 30 / 50
#
# Test set: Average loss: 0.3573, Accuracy: 4243/4999 (85%)
#
# Epoch 31 / 50
#
# Test set: Average loss: 0.2340, Accuracy: 4522/4999 (90%)
#
# Epoch 32 / 50
#
# Test set: Average loss: 0.2437, Accuracy: 4469/4999 (89%)
#
# Epoch 33 / 50
#
# Test set: Average loss: 0.2357, Accuracy: 4524/4999 (91%)
#
# Epoch 34 / 50
#
# Test set: Average loss: 0.2217, Accuracy: 4545/4999 (91%)
#
# Epoch 35 / 50
#
# Test set: Average loss: 0.2263, Accuracy: 4521/4999 (90%)
#
# Epoch 36 / 50
#
# Test set: Average loss: 0.2364, Accuracy: 4511/4999 (90%)
#
# Epoch 37 / 50
#
# Test set: Average loss: 0.2180, Accuracy: 4544/4999 (91%)
#
# Epoch 38 / 50
#
# Test set: Average loss: 0.2681, Accuracy: 4460/4999 (89%)
#
# Epoch 39 / 50
#
# Test set: Average loss: 0.2176, Accuracy: 4535/4999 (91%)
#
# Epoch 40 / 50
#
# Test set: Average loss: 0.2818, Accuracy: 4419/4999 (88%)
#
# Epoch 41 / 50
#
# Test set: Average loss: 0.2309, Accuracy: 4531/4999 (91%)
#
# Epoch 42 / 50
#
# Test set: Average loss: 0.2199, Accuracy: 4548/4999 (91%)
#
# Epoch 43 / 50
#
# Test set: Average loss: 0.2527, Accuracy: 4476/4999 (90%)
#
# Epoch 44 / 50
#
# Test set: Average loss: 0.2209, Accuracy: 4556/4999 (91%)
#
# Epoch 45 / 50
#
# Test set: Average loss: 0.2201, Accuracy: 4549/4999 (91%)
#
# Epoch 46 / 50
#
# Test set: Average loss: 0.2195, Accuracy: 4549/4999 (91%)
#
# Epoch 47 / 50
#
# Test set: Average loss: 0.2163, Accuracy: 4545/4999 (91%)
#
# Epoch 48 / 50
#
# Test set: Average loss: 0.2142, Accuracy: 4578/4999 (92%)
#
# Epoch 49 / 50
#
# Test set: Average loss: 0.2161, Accuracy: 4553/4999 (91%)
#
# Epoch 50 / 50
#
# Test set: Average loss: 0.2490, Accuracy: 4511/4999 (90%)
#
# Best valid accuracy: 0.9159490740740741

# %%
plt.plot(np.arange(1, epochs+1), list_err_tr2, label='Train_err')
plt.plot(np.arange(1, epochs+1), list_err_val2, label='Valid_err')
plt.title('Errors')
plt.legend()

# %%
plt.semilogy(np.arange(1, epochs+1), list_loss_tr2, label='Train_loss')
plt.semilogy(np.arange(1, epochs+1), list_loss_val2, label='Valid_loss')
plt.title('Loss')
plt.legend()

# %% [markdown]
# #### Observations
# Our new model is indeed more performant. The accuracy gap is lower and we reach a better accuracy (around 91.5%).

# %% [markdown]
# ### Different hyperparameters

# %% [markdown]
# ## Visualization
# ### Errors
# Let's visualize some images where our algorithm is wrong

# %%
n_im = 6
counter = 0
worst_examples = []
model.eval()
for batch_idx, (data, target) in enumerate(valid_loader):
    if cuda:
        data, target = data.cuda(), target.cuda()
    data, target = Variable(data, volatile=True), Variable(target).unsqueeze(1).float()
    output = model(data)
    pred = output.data.round()
    for i in range(batch_size):
        if  (output[i]-target[i]).abs().data.mean() > 0.95:
            worst_examples.append([data[i].data.cpu(), output[i].data[0], target[i].data[0]])
            counter += 1
    if counter >= n_im:
        break

# %%
from torchvision.transforms import ToPILImage
torch2pil = ToPILImage()

# %%
plt.figure(figsize=(40,30))
for i in range(n_im):
    plt.subplot(6, 1, i+1)
    plt.imshow(torch2pil(.5*worst_examples[i][0]+.5))
    if worst_examples[i][2] == 1:
        plt.title(f'True: Dog, Pred: Cat ({1-worst_examples[i][1]:.3f})')
    else:
        plt.title(f'True: Cat, Pred: Dog ({worst_examples[i][1]:.3f})')
